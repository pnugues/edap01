# %% [markdown]
# # Extraction of a person's occupations from wikidata
# Example with Obama and others
#
# __author__ = "Pierre Nugues"

# %% [markdown]
# A few imports

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# Setting the presentation options

# %%
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 80
pd.options.display.width = 200

# %% [markdown]
# The query

# %%
prefixes = '''PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
'''

# %%
entity = 'Q1780398'

# Q6279 Joseph Biden
# Q22686 Donald Trump
# Q76 Barack Obama
# Q2740012 Stefan Löfven
# Q4935873 Magdalena Andersson
# Q1780398 Ulf Kristersson
# p: entity to statement
# ps: statement to value
# can be replaced by wdt: (truthy, missing facts)
# See: https://stackoverflow.com/questions/36023098/querying-wikidata-difference-between-p-and-wdt-default-prefix

# %%
english_query = '''
SELECT DISTINCT ?item ?itemLabelOcc (lang(?itemLabel) as ?lang)
WHERE 
{{
    wd:{0} p:P106 ?occupation .
    # ?occupation ps:P106 ?item .
    # ?item rdfs:label ?itemLabelOcc .
    FILTER (lang(?itemLabelOcc) = "en") .
}}
LIMIT 1000'''.format(entity)
print(english_query)
# Out:
# SELECT DISTINCT ?item ?itemLabelOcc (lang(?itemLabel) as ?lang)
# WHERE
# {
#     wd:Q1780398 p:P106 ?occupation .
#     ?occupation ps:P106 ?item .
#     ?item rdfs:label ?itemLabelOcc .
#     FILTER (lang(?itemLabelOcc) = "en") .
# }
# LIMIT 1000

# %% [markdown]
# We query the data from wikidata

# %%
headers = {
    'User-Agent': 'NLP-project/1.0 (pierre.nugues@cs.lth.se)'
}

# %%
url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
data = requests.get(url, 
                    params={'query': prefixes + english_query, 'format': 'json'},
                    headers=headers).json()
data
# Out:
# {'head': {'vars': ['item', 'itemLabelOcc', 'lang']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q82955'},
#     'itemLabelOcc': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'politician'}}]}}

# %% [markdown]
# And we print it

# %%
profession = []
for item in data['results']['bindings']:
    profession.append({
        'id': item.get('item', {}).get('value'),
        'occupation': item.get('itemLabelOcc', {}).get('value'),
        'lang': item.get('itemLabelOcc', {}).get('xml:lang'),
    })

df = pd.DataFrame(profession)
df
# Out:
#                                       id  occupation lang
# 0  http://www.wikidata.org/entity/Q82955  politician   en

# %% [markdown]
# Going multilingual

# %%
multilingual_query = '''
SELECT DISTINCT ?item ?itemLabelOcc (lang(?itemLabel) as ?lang)
WHERE 
{{
    wd:{0} p:P106 ?occupation .
    # ?occupation ps:P106 ?item .
    # ?item rdfs:label ?itemLabelOcc . 
}}
LIMIT 1000'''.format(entity)

# %% [markdown]
# The query

# %%
url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
data = requests.get(url, 
                    params={'query': prefixes + multilingual_query, 'format': 'json'},
                    headers=headers).json()
#data

# %% [markdown]
# And we print it

# %%
profession = []
for item in data['results']['bindings']:
    profession.append({
        'id': item.get('item', {}).get('value'),
        'occupation': item.get('itemLabelOcc', {}).get('value'),
        'lang': item.get('itemLabelOcc', {}).get('xml:lang'),
    })

df = pd.DataFrame(profession)
print(df)
# Out:
#                                         id                occupation       lang
# 0    http://www.wikidata.org/entity/Q82955                 سیاست دان        pnb
# 1    http://www.wikidata.org/entity/Q82955               Kawpaq runa         qu
# 2    http://www.wikidata.org/entity/Q82955                   політік        rue
# 3    http://www.wikidata.org/entity/Q82955               राजनैतिज्ञः         sa
# 4    http://www.wikidata.org/entity/Q82955                  бэлиитик        sah
# 5    http://www.wikidata.org/entity/Q82955                දේශපාලනඥයා         si
# 6    http://www.wikidata.org/entity/Q82955               polijtikere        sma
# 7    http://www.wikidata.org/entity/Q82955               politihkkár        smj
# 8    http://www.wikidata.org/entity/Q82955                politikkár        smn
# 9    http://www.wikidata.org/entity/Q82955                sopolitiki         ss
# 10   http://www.wikidata.org/entity/Q82955                     ፖለቲከኛ         ti
# 11   http://www.wikidata.org/entity/Q82955        jan pi kulupu lawa        tok
# 12   http://www.wikidata.org/entity/Q82955             N'wa politiki         ts
# 13   http://www.wikidata.org/entity/Q82955                  сәясәтче    tt-cyrl
# 14   http://www.wikidata.org/entity/Q82955                   политик        udm
# 15   http://www.wikidata.org/entity/Q82955             politikanmez'        vep
# 16   http://www.wikidata.org/entity/Q82955                  Poliitik        vro
# 17   http://www.wikidata.org/entity/Q82955                  politiko        war
# 18   http://www.wikidata.org/entity/Q82955                პოლიტიკოსი        xmf
# 19   http://www.wikidata.org/entity/Q82955                      政治人物      zh-mo
# 20   http://www.wikidata.org/entity/Q82955                      政治人物      zh-my
# 21   http://www.wikidata.org/entity/Q82955                      政治人物      zh-sg
# 22   http://www.wikidata.org/entity/Q82955              sijosətmədor        tly
# 23   http://www.wikidata.org/entity/Q82955                   политик        lbe
# 24   http://www.wikidata.org/entity/Q82955                  ꠞꠣꠎꠘꠤꠔꠤꠇ        syl
# 25   http://www.wikidata.org/entity/Q82955                 Politikus        mad
# 26   http://www.wikidata.org/entity/Q82955                    ⴰⵙⵔⵜⴰⵏ        zgh
# 27   http://www.wikidata.org/entity/Q82955                 Politiker         de
# 28   http://www.wikidata.org/entity/Q82955                politician         en
# 29   http://www.wikidata.org/entity/Q82955                       政治家         ja
# 30   http://www.wikidata.org/entity/Q82955                 πολιτικός        grc
# 31   http://www.wikidata.org/entity/Q82955                 πολιτικός         el
# 32   http://www.wikidata.org/entity/Q82955                  politico         it
# 33   http://www.wikidata.org/entity/Q82955                  político         es
# 34   http://www.wikidata.org/entity/Q82955                   politik         cs
# 35   http://www.wikidata.org/entity/Q82955                 politiker         br
# 36   http://www.wikidata.org/entity/Q82955                   политик         ru
# 37   http://www.wikidata.org/entity/Q82955                   politik         sk
# 38   http://www.wikidata.org/entity/Q82955                 politicus         la
# 39   http://www.wikidata.org/entity/Q82955       രാഷ്ട്രീയപ്രവർത്തകർ         ml
# 40   http://www.wikidata.org/entity/Q82955                 politiker         sv
# 41   http://www.wikidata.org/entity/Q82955                 politikar         nn
# 42   http://www.wikidata.org/entity/Q82955                  poliitik         et
# 43   http://www.wikidata.org/entity/Q82955                 politiker         da
# 44   http://www.wikidata.org/entity/Q82955                  político         pt
# 45   http://www.wikidata.org/entity/Q82955                 politiker         nb
# 46   http://www.wikidata.org/entity/Q82955                politikari         eu
# 47   http://www.wikidata.org/entity/Q82955                   polityk         pl
# 48   http://www.wikidata.org/entity/Q82955                 פוליטיקאי         he
# 49   http://www.wikidata.org/entity/Q82955              ahli politik         ms
# 50   http://www.wikidata.org/entity/Q82955                polaiteoir         ga
# 51   http://www.wikidata.org/entity/Q82955          քաղաքական գործիչ         hy
# 52   http://www.wikidata.org/entity/Q82955                 политичар         mk
# 53   http://www.wikidata.org/entity/Q82955                 politikan         sq
# 54   http://www.wikidata.org/entity/Q82955                রাজনীতিবিদ         bn
# 55   http://www.wikidata.org/entity/Q82955                 politikus         id
# 56   http://www.wikidata.org/entity/Q82955                 politicus         nl
# 57   http://www.wikidata.org/entity/Q82955                   політик         uk
# 58   http://www.wikidata.org/entity/Q82955                  Amanyɔni         tw
# 59   http://www.wikidata.org/entity/Q82955    personnalité politique         fr
# 60   http://www.wikidata.org/entity/Q82955                  político         gl
# 61   http://www.wikidata.org/entity/Q82955                     سياسي         ar
# 62   http://www.wikidata.org/entity/Q82955                 politikus         af
# 63   http://www.wikidata.org/entity/Q82955               அரசியல்வாதி         ta
# 64   http://www.wikidata.org/entity/Q82955                politician         ro
# 65   http://www.wikidata.org/entity/Q82955                     سياسي        acm
# 66   http://www.wikidata.org/entity/Q82955                  Politico         an
# 67   http://www.wikidata.org/entity/Q82955                 politikus         hu
# 68   http://www.wikidata.org/entity/Q82955                   polític         ca
# 69   http://www.wikidata.org/entity/Q82955                      政治人物    zh-hans
# 70   http://www.wikidata.org/entity/Q82955                राजनीतिज्ञ         hi
# 71   http://www.wikidata.org/entity/Q82955                       정치인         ko
# 72   http://www.wikidata.org/entity/Q82955                 سیاستمدار         fa
# 73   http://www.wikidata.org/entity/Q82955                პოლიტიკოსი         ka
# 74   http://www.wikidata.org/entity/Q82955                 siyasetçi         tr
# 75   http://www.wikidata.org/entity/Q82955            နိုင်ငံရေးသမား         my
# 76   http://www.wikidata.org/entity/Q82955                   Siyaasi         so
# 77   http://www.wikidata.org/entity/Q82955                  Polidika        bar
# 78   http://www.wikidata.org/entity/Q82955                      政治人物         zh
# 79   http://www.wikidata.org/entity/Q82955                      政治人物      zh-tw
# 80   http://www.wikidata.org/entity/Q82955                  سياستوال         ps
# 81   http://www.wikidata.org/entity/Q82955               ᱨᱟᱡᱽᱟᱹᱨᱤᱭᱟᱹ        sat
# 82   http://www.wikidata.org/entity/Q82955                   politik         sl
# 83   http://www.wikidata.org/entity/Q82955               politikisto         eo
# 84   http://www.wikidata.org/entity/Q82955                   olóṣèlú         yo
# 85   http://www.wikidata.org/entity/Q82955                politician      en-ca
# 86   http://www.wikidata.org/entity/Q82955  Onye ndọrọ ndọrọ ọchịchị         ig
# 87   http://www.wikidata.org/entity/Q82955                politician      en-gb
# 88   http://www.wikidata.org/entity/Q82955                politician      en-us
# 89   http://www.wikidata.org/entity/Q82955                 siyasətçi         az
# 90   http://www.wikidata.org/entity/Q82955                  político      pt-br
# 91   http://www.wikidata.org/entity/Q82955                ɗan siyasa         ha
# 92   http://www.wikidata.org/entity/Q82955                  políticu        ast
# 93   http://www.wikidata.org/entity/Q82955                   палітык  be-tarask
# 94   http://www.wikidata.org/entity/Q82955                poliitikko         fi
# 95   http://www.wikidata.org/entity/Q82955                 gwleidydd         cy
# 96   http://www.wikidata.org/entity/Q82955                       政治人        yue
# 97   http://www.wikidata.org/entity/Q82955                  politegh        lmo
# 98   http://www.wikidata.org/entity/Q82955                  ರಾಜಕಾರಣಿ         kn
# 99   http://www.wikidata.org/entity/Q82955                 политичар         sr
# 100  http://www.wikidata.org/entity/Q82955                 Politiker      de-at
# 101  http://www.wikidata.org/entity/Q82955                   политик         bg
# 102  http://www.wikidata.org/entity/Q82955                      政治人物    zh-hant
# 103  http://www.wikidata.org/entity/Q82955                 سیاست دان         ur
# 104  http://www.wikidata.org/entity/Q82955               politikisto         io
# 105  http://www.wikidata.org/entity/Q82955                siyasatshı        kaa
# 106  http://www.wikidata.org/entity/Q82955                 političar         hr
# 107  http://www.wikidata.org/entity/Q82955                 političar         bs
# 108  http://www.wikidata.org/entity/Q82955                  politiko        pap
# 109  http://www.wikidata.org/entity/Q82955                 Politiker         lb
# 110  http://www.wikidata.org/entity/Q82955                  politiko         tl
# 111  http://www.wikidata.org/entity/Q82955                  ਸਿਆਸਤਦਾਨ         pa
# 112  http://www.wikidata.org/entity/Q82955                   палітык         be
# 113  http://www.wikidata.org/entity/Q82955              سِیاسَتھ دان         ks
# 114  http://www.wikidata.org/entity/Q82955                राजनीतिज्ञ         ne
# 115  http://www.wikidata.org/entity/Q82955                 politikus         fy
# 116  http://www.wikidata.org/entity/Q82955               сиёсатмадор         tg
# 117  http://www.wikidata.org/entity/Q82955                   سیاستچی        azb
# 118  http://www.wikidata.org/entity/Q82955                ରାଜନୀତିଜ୍ଞ         or
# 119  http://www.wikidata.org/entity/Q82955                     سياسى        arz
# 120  http://www.wikidata.org/entity/Q82955                  سياستدان         sd
# 121  http://www.wikidata.org/entity/Q82955                 Politiker      de-ch
# 122  http://www.wikidata.org/entity/Q82955                   политик         os
# 123  http://www.wikidata.org/entity/Q82955                     سياسي        ary
# 124  http://www.wikidata.org/entity/Q82955                 politikar        hsb
# 125  http://www.wikidata.org/entity/Q82955                  politiku         mt
# 126  http://www.wikidata.org/entity/Q82955               chính khách         vi
# 127  http://www.wikidata.org/entity/Q82955            munnabyabufuzi         lg
# 128  http://www.wikidata.org/entity/Q82955               นักการเมือง         th
# 129  http://www.wikidata.org/entity/Q82955                  Улс төрч         mn
# 130  http://www.wikidata.org/entity/Q82955                 саясаткер         kk
# 131  http://www.wikidata.org/entity/Q82955                siyosatchi         uz
# 132  http://www.wikidata.org/entity/Q82955               politiciste        lfn
# 133  http://www.wikidata.org/entity/Q82955                   bolitan         vo
# 134  http://www.wikidata.org/entity/Q82955                  lugayhon        ceb
# 135  http://www.wikidata.org/entity/Q82955                politikari         fo
# 136  http://www.wikidata.org/entity/Q82955         neach-poileataigs         gd
# 137  http://www.wikidata.org/entity/Q82955                 Politiker        gsw
# 138  http://www.wikidata.org/entity/Q82955               politickeyr         gv
# 139  http://www.wikidata.org/entity/Q82955                  politico         ia
# 140  http://www.wikidata.org/entity/Q82955                  politiko        ilo
# 141  http://www.wikidata.org/entity/Q82955           stjórnmálamaður         is
# 142  http://www.wikidata.org/entity/Q82955                Polleteker        ksh
# 143  http://www.wikidata.org/entity/Q82955                 politeger         kw
# 144  http://www.wikidata.org/entity/Q82955                 Politicus         li
# 145  http://www.wikidata.org/entity/Q82955                  polìtico        lij
# 146  http://www.wikidata.org/entity/Q82955                 politikas         lt
# 147  http://www.wikidata.org/entity/Q82955           mpanao politika         mg
# 148  http://www.wikidata.org/entity/Q82955                 Politiker        nds
# 149  http://www.wikidata.org/entity/Q82955               poliitiekku        olo
# 150  http://www.wikidata.org/entity/Q82955                politicher         rm
# 151  http://www.wikidata.org/entity/Q82955                  pulìticu        scn
# 152  http://www.wikidata.org/entity/Q82955               politeecian        sco
# 153  http://www.wikidata.org/entity/Q82955               politihkkár         se
# 154  http://www.wikidata.org/entity/Q82955                 političar         sh
# 155  http://www.wikidata.org/entity/Q82955                politician         sw
# 156  http://www.wikidata.org/entity/Q82955                 Politiker        szl
# 157  http://www.wikidata.org/entity/Q82955                  pułìtego        vec
# 158  http://www.wikidata.org/entity/Q82955                  Politikî         wa
# 159  http://www.wikidata.org/entity/Q82955               usombusazwe         zu
# 160  http://www.wikidata.org/entity/Q82955                 политичар      sr-ec
# 161  http://www.wikidata.org/entity/Q82955                 političar      sr-el
# 162  http://www.wikidata.org/entity/Q82955                  राजकारणी         mr
# 163  http://www.wikidata.org/entity/Q82955                      政治人物      zh-cn
# 164  http://www.wikidata.org/entity/Q82955                  сәйәсмән         ba
# 165  http://www.wikidata.org/entity/Q82955                  сәясәтче         tt
# 166  http://www.wikidata.org/entity/Q82955                Politisyen         ht
# 167  http://www.wikidata.org/entity/Q82955                 politiķis         lv
# 168  http://www.wikidata.org/entity/Q82955                राजनीतिज्ञ        mai
# 169  http://www.wikidata.org/entity/Q82955                  રાજકારણી         gu
# 170  http://www.wikidata.org/entity/Q82955               politikkneǩ        sms
# 171  http://www.wikidata.org/entity/Q82955                 سیاستمدار        mzn
# 172  http://www.wikidata.org/entity/Q82955                 פאליטיקער         yi
# 173  http://www.wikidata.org/entity/Q82955            రాజకీయ నాయకులు         te
# 174  http://www.wikidata.org/entity/Q82955                ৰাজনীতিবিদ         as
# 175  http://www.wikidata.org/entity/Q82955                      政治人物      zh-hk
# 176  http://www.wikidata.org/entity/Q82955                      政治人物        wuu
# 177  http://www.wikidata.org/entity/Q82955                   asertay        kab
# 178  http://www.wikidata.org/entity/Q82955                Siyasetkar        diq
# 179  http://www.wikidata.org/entity/Q82955                  аполитик         ab
# 180  http://www.wikidata.org/entity/Q82955                     ፖለቲከኛ         am
# 181  http://www.wikidata.org/entity/Q82955                  Сиясатчи         av
# 182  http://www.wikidata.org/entity/Q82955                   राजनेता        awa
# 183  http://www.wikidata.org/entity/Q82955                Anakithiri         ay
# 184  http://www.wikidata.org/entity/Q82955                  politiko        bcl
# 185  http://www.wikidata.org/entity/Q82955             Tokoh pulitik        bew
# 186  http://www.wikidata.org/entity/Q82955               улас түрэшэ        bxr
# 187  http://www.wikidata.org/entity/Q82955                  político    cbk-zam
# 188  http://www.wikidata.org/entity/Q82955                céng-dê-gă        cdo
# 189  http://www.wikidata.org/entity/Q82955                   политик         ce
# 190  http://www.wikidata.org/entity/Q82955                 سیاسەتوان        ckb
# 191  http://www.wikidata.org/entity/Q82955                  puliticu         co
# 192  http://www.wikidata.org/entity/Q82955                 siyasetçi        crh
# 193  http://www.wikidata.org/entity/Q82955                 siyasetçi   crh-latn
# 194  http://www.wikidata.org/entity/Q82955                   pòlitik        csb
# 195  http://www.wikidata.org/entity/Q82955                   политик         cv
# 196  http://www.wikidata.org/entity/Q82955                 Pɔleteesa        dga
# 197  http://www.wikidata.org/entity/Q82955             aŋiɛcwëlbääny        din
# 198  http://www.wikidata.org/entity/Q82955                 politikaŕ        dsb
# 199  http://www.wikidata.org/entity/Q82955             tulun pulitik        dtp
# 200  http://www.wikidata.org/entity/Q82955                  políticu        ext
# 201  http://www.wikidata.org/entity/Q82955        ngaɗoowo siyaasaje         ff
# 202  http://www.wikidata.org/entity/Q82955                 politiker        frr
# 203  http://www.wikidata.org/entity/Q82955             ojokuaikuaáva         gn
# 204  http://www.wikidata.org/entity/Q82955                  tonudọtọ        guw
# 205  http://www.wikidata.org/entity/Q82955            chṳn-chhṳ-ngìn        hak
# 206  http://www.wikidata.org/entity/Q82955           loea kālaiʻāina        haw
# 207  http://www.wikidata.org/entity/Q82955                  politiko        hil
# 208  http://www.wikidata.org/entity/Q82955          քաղաքական գործիչ        hyw
# 209  http://www.wikidata.org/entity/Q82955     a̱tyukwainfwuo-á̱niet        kcg
# 210  http://www.wikidata.org/entity/Q82955                  politiko        krj
# 211  http://www.wikidata.org/entity/Q82955              siyasetmedar         ku
# 212  http://www.wikidata.org/entity/Q82955              siyasetmedar    ku-latn
# 213  http://www.wikidata.org/entity/Q82955              Moí-politíki         ln
# 214  http://www.wikidata.org/entity/Q82955               ນັກການເມືອງ         lo
# 215  http://www.wikidata.org/entity/Q82955                 политиксь        mdf
# 216  http://www.wikidata.org/entity/Q82955                   политик        mhr
# 217  http://www.wikidata.org/entity/Q82955              kaitōrangapū         mi
# 218  http://www.wikidata.org/entity/Q82955                 politikus        min
# 219  http://www.wikidata.org/entity/Q82955              اهلي ڤوليتيک    ms-arab
# 220  http://www.wikidata.org/entity/Q82955           вийкирдий-ветий        myv
# 221  http://www.wikidata.org/entity/Q82955                  Cemitqui        nah
# 222  http://www.wikidata.org/entity/Q82955         Chèng-tī jîn-bu̍t        nan
# 223  http://www.wikidata.org/entity/Q82955             ߓߘߍ߬ߓߘߍ߬ߟߌ߬ߟߊ        nqo
# 224  http://www.wikidata.org/entity/Q82955                   politic         oc
# 225  http://www.wikidata.org/entity/Q82955                  politiko        pag
# 226  http://www.wikidata.org/entity/Q82955                  polítiku        pam
